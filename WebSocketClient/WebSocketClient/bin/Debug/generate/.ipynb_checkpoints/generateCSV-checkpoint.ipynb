# %%
import pandas as pd
from pandas import DataFrame

import datetime
import pandas_datareader as pdr

import matplotlib.pyplot as plt

import glob, os

#On va chercher les CSV

#on va générer les csv des moyennes pour chaque Angle
#On va parcourir tous les CSV ayant la même distance pour un angle
#Faire la moyenne des données dans le fichier CSV
#...

#Path courant
cwd = os.getcwd()

os.chdir("C:/Users/laure/source/repos/WebSocketClientCSharp/WebSocketClient/WebSocketClient/bin/Debug/xp/")

for file in glob.glob("*.csv"):
    #nom du fichier
    print(file)
    
    
df = pd.read_csv('C:/Users/laure/source/repos/WebSocketClientCSharp/WebSocketClient/WebSocketClient/bin/Debug/xp/test.csv',sep=';',index_col='timestamp',parse_dates=True)

print(df)

df=df.astype(float)

df['rssi8'].plot()

average = df['rssi8'].mean()
print(average)

nb = df.shape[0]
print(n)

plt.show()
# Out:
# Sel_0_0.csv
# Sel_100_0.csv
# Sel_100_180.csv
# Sel_10_0.csv
# Sel_120_180.csv
# Sel_120_90.csv
# Sel_15_0.csv
# Sel_15_90.csv
# Sel_25_23.csv
# Sel_40_90.csv
# Sel_5_0.csv
# Sel_60_45.csv
# test.csv
#                      rssi8
# timestamp
# 2018-05-14 16:47:47  -40.0
# 2018-05-14 16:47:48  -40.0
# 2018-05-14 16:47:48  -40.0
# 2018-05-14 16:47:48  -40.0
# 2018-05-14 16:47:48  -40.0
# 2018-05-14 16:47:49  -40.5
# 2018-05-14 16:47:49  -40.5
# 2018-05-14 16:47:49  -40.0
# 2018-05-14 16:47:49  -39.5
# 2018-05-14 16:47:50  -39.5
# 2018-05-14 16:47:50  -39.5
# 2018-05-14 16:47:50  -70.0
# 2018-05-14 16:47:50  -39.5
# 2018-05-14 16:47:50  -40.0
# 2018-05-14 16:47:51  -39.0
# 2018-05-14 16:47:51  -39.0
# 2018-05-14 16:47:51  -38.0
# 2018-05-14 16:47:51  -40.0
# 2018-05-14 16:47:52  -37.0
# 2018-05-14 16:47:52  -36.5
# 2018-05-14 16:47:52  -40.0
# 2018-05-14 16:47:52  -39.0
# 2018-05-14 16:47:53  -40.0
# 2018-05-14 16:47:53  -40.0
# 2018-05-14 16:47:53  -39.5
# 2018-05-14 16:47:53  -40.0
# ...

# %%
import pandas as pd
from pandas import DataFrame

import datetime
import pandas_datareader as pdr

import matplotlib.pyplot as plt

import glob, os

#On va chercher les CSV

#on va générer les csv des moyennes pour chaque Angle
os.chdir("C:/Users/laure/source/repos/WebSocketClientCSharp/WebSocketClient/WebSocketClient/bin/Debug/xp/")
for file in glob.glob("*.csv"):
    #nom du fichier
    print(file)
    
    #le fichier courant sera donc pris
    df = pd.read_csv(file,sep=';',index_col='timestamp',parse_dates=True)
# Out:
# Sel_0_0.csv
# Sel_100_0.csv
# Sel_100_180.csv
# Sel_10_0.csv
# Sel_120_180.csv
# Sel_120_90.csv
# Sel_15_0.csv
# Sel_15_90.csv
# Sel_25_23.csv
# Sel_40_90.csv
# Sel_5_0.csv
# Sel_60_45.csv
# test.csv
